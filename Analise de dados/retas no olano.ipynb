# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 3, 4],[1, 10, 7, 8], label='sala1', color='red', linestyle='--')
plt.plot([1, 2, 3, 4],[1, 15, 9, 12], label='sala2')
plt.ylabel('Label y')
plt.xlabel('Label x')
plt.legend()
plt.title('Primeiro gráfico')
# Out:
# Text(0.5, 1.0, 'Primeiro gráfico')
